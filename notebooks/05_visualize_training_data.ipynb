# %% [markdown]
# ### Visualize the data before passing the data to the model for better understanding the data

# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Courses\\Pau_ML_course\\notebooks'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'd:\\Courses\\Pau_ML_course'

# %%
import pandas as pd
from src.paths import TRANSFORMED_DATA_DIR

# %%
features_and_target = pd.read_parquet(TRANSFORMED_DATA_DIR / "tabular_data.parquet")
features_and_target
# Out:
#        rides_previous_672_hour  rides_previous_671_hour  \
# 0                         11.0                     15.0
# 1                          1.0                      0.0
# 2                          0.0                      1.0
# 3                          1.0                      1.0
# 4                          0.0                      0.0
# ...                        ...                      ...
# 88289                      0.0                      0.0
# 88290                      0.0                      0.0
# 88291                      0.0                      0.0
# 88292                      0.0                      0.0
# 88293                      0.0                      0.0
#
#        rides_previous_670_hour  rides_previous_669_hour  \
# 0                         26.0                      8.0
# 1                          2.0                      0.0
# 2                          0.0                      0.0
# 3                          0.0                      0.0
# ...

# %% [markdown]
# ### Split the features and target into 2 separate dataframes

# %%
features = features_and_target.drop(columns=["target_rides_next_hour"])
target = features_and_target["target_rides_next_hour"]
